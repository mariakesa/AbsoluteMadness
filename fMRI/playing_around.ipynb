# %%
from nilearn import datasets

print(f"Datasets are stored in: {datasets.get_data_dirs()!r}")
# Out:
# Datasets are stored in: ['/home/maria/nilearn_data']

# %%
motor_images = datasets.fetch_neurovault_motor_task()
motor_images.images
# Out:
# Added README.md to /home/maria/nilearn_data
#
#
# Dataset created in /home/maria/nilearn_data/neurovault
# ['/home/maria/nilearn_data/neurovault/collection_658/image_10426.nii.gz']

# %%
tmap_filename = motor_images.images[0]

# %%
from nilearn import plotting

plotting.plot_stat_map(tmap_filename)

# %%
from nilearn import datasets

atlas = datasets.fetch_atlas_msdl()
# Out:
# Dataset created in /home/maria/nilearn_data/msdl_atlas
#
# Downloading data from https://team.inria.fr/parietal/files/2015/01/MSDL_rois.zip ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /home/maria/nilearn_data/msdl_atlas/8eaecb9e05c478f565847000d9902a25/MSDL_rois.zip..... done.
